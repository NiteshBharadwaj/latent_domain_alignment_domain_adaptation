# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img=mpimg.imread('./data/CCWeb/data/image/149/1796/2010/f096eef12e0214.jpg')

# %%
imgplot = plt.imshow(img)

# %%
plt.show()

# %%
img=mpimg.imread('./data_cropped/149/1796/2010/f096eef12e0214.jpg')

# %%
imgplot = plt.imshow(img)
